# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('finalData.csv')

# %%
df.head()
# Out:
#                                 Restaurant Name   Area Restaurant type  \
# 0                           Cricket Ground Cafe  Badda            Cafe
# 1                           Rosemery Restaurant  Badda     Bangladeshi
# 2                            Sanxi Thai Chinese  Badda         Chinese
# 3                                 The Artichoke  Badda      Restaurant
# 4  Cabana Restaurant and Party Center(Roof Top)  Badda      Restaurant
#
#    Ratings  Number of ratings  price  \
# 0      4.1                169      1
# 1      3.9                369      1
# 2      3.9               1102      2
# 3      4.4                178      1
# 4      4.0                143      2
#
#                                              Address
# 0            171/3 Middle Badda, হাতির ঝিল লিঙ্ক রোড
# 1                                         Madani Ave
# 2                          House#1/B, Road#13, South
# 3  Arma Majeda Malik Tower , Holding No# 215, Bir...
# 4  House 04, Road -10, DIT Project, Merul Badda D...

# %%
#Assign weight based on ratings and price

# %%
v = df['Number of ratings']
R = df['Ratings']
C = df['Ratings'].mean()
m = df['Number of ratings'].quantile(0.60)
price = df['price']
df['weighted_average'] = (((R*v)+(C*m))/(v+m))
df['price_average'] = (3/df['price'])

# %%
df.head()
# Out:
#                                 Restaurant Name   Area Restaurant type  \
# 0                           Cricket Ground Cafe  Badda            Cafe
# 1                           Rosemery Restaurant  Badda     Bangladeshi
# 2                            Sanxi Thai Chinese  Badda         Chinese
# 3                                 The Artichoke  Badda      Restaurant
# 4  Cabana Restaurant and Party Center(Roof Top)  Badda      Restaurant
#
#    Ratings  Number of ratings  price  \
# 0      4.1                169      1
# 1      3.9                369      1
# 2      3.9               1102      2
# 3      4.4                178      1
# 4      4.0                143      2
#
#                                              Address  weighted_average  \
# 0            171/3 Middle Badda, হাতির ঝিল লিঙ্ক রোড          4.030678
# 1                                         Madani Ave          3.967601
# 2                          House#1/B, Road#13, South          3.938162
# 3  Arma Majeda Malik Tower , Holding No# 215, Bir...          4.101837
# 4  House 04, Road -10, DIT Project, Merul Badda D...          4.008444
#
#    price_average
# 0            3.0
# 1            3.0
# 2            1.5
# 3            3.0
# 4            1.5

# %%
#Assign score 90 precent weight and 10 percent price
df['score'] = df['weighted_average']*0.90 + df['price_average']*0.10

# %%
df.head(5)
# Out:
#                                 Restaurant Name   Area Restaurant type  \
# 0                           Cricket Ground Cafe  Badda            Cafe
# 1                           Rosemery Restaurant  Badda     Bangladeshi
# 2                            Sanxi Thai Chinese  Badda         Chinese
# 3                                 The Artichoke  Badda      Restaurant
# 4  Cabana Restaurant and Party Center(Roof Top)  Badda      Restaurant
#
#    Ratings  Number of ratings  price  \
# 0      4.1                169      1
# 1      3.9                369      1
# 2      3.9               1102      2
# 3      4.4                178      1
# 4      4.0                143      2
#
#                                              Address  weighted_average  \
# 0            171/3 Middle Badda, হাতির ঝিল লিঙ্ক রোড          4.030678
# 1                                         Madani Ave          3.967601
# 2                          House#1/B, Road#13, South          3.938162
# 3  Arma Majeda Malik Tower , Holding No# 215, Bir...          4.101837
# 4  House 04, Road -10, DIT Project, Merul Badda D...          4.008444
#
#    price_average     score
# 0            3.0  3.927610
# 1            3.0  3.870841
# 2            1.5  3.694346
# 3            3.0  3.991654
# 4            1.5  3.757599

# %%
#Content based recommendation:

# %%
from sklearn.preprocessing import LabelEncoder
le_area = LabelEncoder()
le_type = LabelEncoder()
df['area_value'] = le_area.fit_transform(df['Area'])
df['type_value'] = le_type.fit_transform(df['Restaurant type'])

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
df['area_value'] = scaler.fit_transform(df[['area_value']])
df['type_value'] = scaler.fit_transform(df[['type_value']])
df['Ratings_value'] = scaler.fit_transform(df[['Ratings']])
df['Number of ratings value'] = scaler.fit_transform(df[['Number of ratings']])
df['price_value'] = scaler.fit_transform(df[['price']])

# %%
X = df[['Ratings_value','price_value','area_value','type_value','Number of ratings value']]
X
# Out:
#      Ratings_value  price_value  area_value  type_value  \
# 0         0.578947          0.0         0.0    0.229167
# 1         0.473684          0.0         0.0    0.083333
# 2         0.473684          0.5         0.0    0.312500
# 3         0.736842          0.0         0.0    0.833333
# 4         0.526316          0.5         0.0    0.833333
# ..             ...          ...         ...         ...
# 993       0.526316          0.0         1.0    0.833333
# 994       0.526316          0.5         1.0    0.833333
# 995       0.263158          0.0         1.0    0.229167
# 996       0.631579          0.5         1.0    0.979167
# 997       0.631579          0.5         1.0    0.791667
#
#      Number of ratings value
# 0                   0.006217
# 1                   0.016667
# 2                   0.054963
# 3                   0.006688
# 4                   0.004859
# ..                       ...
# 993                 0.006792
# 994                 0.019122
# 995                 0.004963
# 996                 0.057367
# 997                 0.001202
#
# [998 rows x 5 columns]

# %%
from sklearn.metrics.pairwise import cosine_similarity
newArray = cosine_similarity(X,X)

# %%
indices = pd.Series(df.index, index=df['Restaurant Name']).drop_duplicates()

# %%
def get_recommendations(title, cosine_sim=newArray):
    # Get the index of the movie that matches the title
    idx = indices[title]

    # Get the pairwsie similarity scores of all movies with that movie
    sim_scores = list(enumerate(cosine_sim[idx]))
        
    # Sort the movies based on the similarity scores
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # Get the scores of the 10 most similar movies
    sim_scores = sim_scores[1:11]

    # Get the movie indices
    movie_indices = [i[0] for i in sim_scores]

    # Return the top 10 most similar movies
    return df[['Restaurant Name','Area','Restaurant type','price','Ratings']].iloc[movie_indices]

# %%
def searchRestaurant(area, rest_type, price):
    newDf = df[(df['Area'] == area)&(df['Restaurant type'] == rest_type)&(df['price'] == int(price))]
    newDf = newDf.sort_values('score', ascending= False)
    return newDf[['Restaurant Name','Area','Restaurant type','price','Ratings','score']]

# %%
area = input("enter restaurant area: ")
restType = input("enter restaurant type: ")
price = input("enter restaurant price: ")
searchRestaurant(area,restType,price)
# Out:
# enter restaurant area: Dhanmondi
# enter restaurant type: Restaurant
# enter restaurant price: 3
#                          Restaurant Name       Area Restaurant type  price  \
# 345                      Absolute BBQ BD  Dhanmondi      Restaurant      3
# 283  The Great Kabab Factory (Dhanmondi)  Dhanmondi      Restaurant      3
# 243                    The Forest Lounge  Dhanmondi      Restaurant      3
# 238                    The Stubborn Goat  Dhanmondi      Restaurant      3
# 232                  Flavours Music Cafe  Dhanmondi      Restaurant      3
#
#      Ratings     score
# 345      4.3  3.906913
# 283      4.2  3.802882
# 243      4.1  3.770573
# 238      4.0  3.705265
# 232      3.6  3.490988

# %%
get_recommendations("")
# Out:
#                      Restaurant Name      Area Restaurant type  price  Ratings
# 48                      Herfy Banani    Banani       Fast Food      2      4.2
# 25                               KFC    Banani       Fast Food      2      4.0
# 50                       Urban Spoon    Banani       Fast Food      2      4.1
# 49            Madchef Banani, Dhaka.    Banani       Fast Food      2      4.3
# 141                              KFC  Banasree       Fast Food      2      3.9
# 88                  Sajna Restaurant    Banani          Indian      2      4.1
# 110                       New Cathay    Banani         Chinese      2      3.9
# 2                 Sanxi Thai Chinese     Badda         Chinese      2      3.9
# 39   Cheong Shing Restaurant, Dhaka.    Banani         Chinese      2      4.2
# 70                       KFD Express    Banani         Chinese      2      4.3
